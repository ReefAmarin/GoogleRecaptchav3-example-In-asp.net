# %% [markdown]
# <a href="https://colab.research.google.com/github/ReefAmarin/GoogleRecaptchav3-example-In-asp.net/blob/master/Copy_of_Copy_of_Taqwa_simple_line_plot_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Simple line plot**

# %% [markdown]
# ** Perhaps the simplest of all plots is the visualization of a single function  y=f(x) .As with all the following sections, we'll start by setting up the notebook for plotting and importing the packages we will use:**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# **we start by creating a figure and an axes**.

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax1 = plt.axes()
ax2 = plt.axes()

x = np.linspace(0, 10, 1000)
ax1.plot(x, np.sin(x));
ax2.plot(x, np.cos(x));
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# **Adjusting the Plot: Axes Limits**

# %%
plt.plot(x, np.sin(x))

plt.xlim(0, 10)
plt.ylim(-1, 1);

# %% [markdown]
# The plt.axis() method allows you to set the x and y limits with a single call, by passing a list which specifies [xmin, xmax, ymin, ymax]:

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
fig=plt.figure()
ax=plt.axes()
ax.plot(x, np.sin(x))
ax.axis('equal'); 
#ax.xlim(0,4) 
ax.set_xlim(0,8)
# Out:
# (0.0, 8.0)

# %% [markdown]
# **Adjusting the Plot: Line Colors and Styles**

# %% [markdown]
# You do not need to use format strings, which are just abbreviations. All of the line properties can be controlled by keyword arguments. For example, you can set the color, marker, linestyle, and markercolor with:

# %%
plt.plot

# %% [markdown]
# plot(x, y, color='green', linestyle='dashed', marker='o',
#      markerfacecolor='blue', markersize=12).

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %%
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
mycolor_pal=['#FFFF00','#C8A4BA','#C8B4BA','#C8B4BA','#C8B4BA']

# %%
plt.plot(x, (x - 0),':', color='blue')        # specify color by name
plt.plot(x, (x - 1), '--',color='r')           # short color code (rgbcmyk)
plt.plot(x, (x - 2),'*-', color='0.8')        # Grayscale between 0 and 1
plt.plot(x, (x - 3), color=mycolor_pal[0])     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, (x - 4), color=(0.128,0.128,0)) # RGB tuple, values 0 to 1
plt.plot(x, (x - 5), color='chocolate'); # all HTML color names supported

# %% [markdown]
# **Example format strings:**

# %% [markdown]
# ![44.PNG](data:image/png;base64,...)

# %%
'b'    # blue markers with default shape
'or'   # red circles
'-g'   # green solid line
'--'   # dashed line with default color
'^k:'  # black triangle_up markers connected by a dotted line
# Out:
# '^k:'

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t**2, 'r--', t, t**3, 'bs', t, t*2, 'g^')
plt.show()

# %% [markdown]
# **Labeling Plots**

# %% [markdown]
# 1-Titles and axis labels

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# For transitioning between MATLAB-style functions and object-oriented methods, make the following changes:

# %% [markdown]
# plt.xlabel() → ax.set_xlabel()
#
# plt.ylabel() → ax.set_ylabel()
#
# plt.xlim() → ax.set_xlim()
#
# plt.ylim() → ax.set_ylim()
#
# plt.title() → ax.set_title()

# %%
ax=plt.axes()
ax.plot(x, np.sin(x))
ax.set_title("A Sine Curve")
ax.set_xlabel("x")
ax.set_ylabel("sin(x)");
ax.legend(["sin(x)"]);

# %% [markdown]
#  **Matplotlib Gotchas**

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set( xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot')
# Out:
# [(-2.0, 2.0),
#  Text(0, 0.5, 'sin(x)'),
#  (0.0, 10.0),
#  Text(0.5, 0, 'x'),
#  Text(0.5, 1.0, 'A Simple Plot')]

# %%
import pandas as pd
df=pd.read_csv('/content/Salary_Data.csv')
x = df['YearsExperience'].values
y = df['Salary'].values

plt.plot(x,y,label = 'Real Data',linestyle=':',color = 'k',marker='^',markerfacecolor='b',markersize='8')
plt.grid()
plt.xlabel('Years of Experience')
plt.ylabel('Salary ($)')
plt.show()
# Out:
# Text(0, 0.5, 'Salary ($)')

# %% [markdown]
# **Hands-on**

# %% [markdown]
# Generated the following line plot must include following Style properties: –
#
# Line width should be 3

# %%
 import requests
import io
import pandas as pd

response = requests.get('https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv')

file_object = io.StringIO(response.content.decode('utf-8'))
df=pd.read_csv(file_object)
x = df['month_number'].values
y = df['total_profit'].values


plt.plot(x,y,label = 'Real Data',linestyle='--',color = 'r',marker='o',markerfacecolor='k',markersize='8')
plt.grid()
plt.xlabel('monthList')
plt.ylabel('profitList')
plt.show()

# %% [markdown]
# Part 2:
# 4 subplots (grid, 2X2)
# x---> month number
# y----> profitList, total_units, moisturizerm, facewash
# Add x and y lables, legends, and use the above commands to imporve the style of the figure.
# limit x axis to months [JAN to JUN]
# [2]

# %%
from urllib.request import Request, urlopen  # Python 3

# %%
req = Request(url)
req.add_header('User-Agent', 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0')
content = urlopen(req)

df = pd.read_csv(content)
print(df)
# Out:
#     month_number  facecream  facewash  ...  moisturizer  total_units  total_profit
# 0              1       2500      1500  ...         1500        21100        211000
# 1              2       2630      1200  ...         1200        18330        183300
# 2              3       2140      1340  ...         1340        22470        224700
# 3              4       3400      1130  ...         1130        22270        222700
# 4              5       3600      1740  ...         1740        20960        209600
# 5              6       2760      1555  ...         1555        20140        201400
# 6              7       2980      1120  ...         1120        29550        295500
# 7              8       3700      1400  ...         1400        36140        361400
# 8              9       3540      1780  ...         1780        23400        234000
# 9             10       1990      1890  ...         1890        26670        266700
# ...

# %%
# import pandas as pd
# url="https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv"
# df=pd.read_csv(url)
monthList  = df ['month_number'].tolist()
profitList = df ['total_profit'].tolist()
total_units=df ['total_units'].tolist()
moisturizer=df.moisturizer.tolist()
facewash=df.facewash.tolist()

# %%
import requests
import io
import pandas as pd

response = requests.get('https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv')

file_object = io.StringIO(response.content.decode('utf-8'))
df=pd.read_csv(file_object)
x = df['month_number'].values
y = df['total_profit'].values


plt.plot(x,y,label = 'Real Data',linestyle='--',color = 'r',marker='o',markerfacecolor='k',markersize='8')
plt.grid()
plt.xlabel('monthList')
plt.ylabel('profitList')
plt.show()
